# %% [markdown]
# # COVID-19 : INDIA ANALYSIS
# <hr>
# ### Introduction
# ![corona](https://images.unsplash.com/photo-1583324113626-70df0f4deaab?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=1000&q=80)
# > Coronavirus is a family of viruses that can cause illness, which can vary from common cold and cough to sometimes more severe disease. Middle East Respiratory Syndrome (MERS-CoV) and Severe Acute Respiratory Syndrome (SARS-CoV) were such severe cases with the world already has faced.
# SARS-CoV-2 (n-coronavirus) is the new virus of the coronavirus family, which first discovered in 2019, which has not been identified in humans before. It is a contiguous virus which started from Wuhan in December 2019. Which later declared as Pandemic by WHO due to high rate spreads throughout the world. Currently (on the date 5 May 2020), this leads to a total of 251K+ Deaths across the globe.
# Pandemic is spreading all over the world; it becomes more important to understand about this spread. This NoteBook is an effort to analyze the cumulative data of confirmed, deaths, and recovered cases over time. In this notebook, the main focus is to analyze the spread trend of this virus all over the world.
#
# > In India the first case was reported on 28 Jan, 2020, and as of now (20 Sept, 2020) more than 5M cases have been reported. More than 80K peoples have been died so far.
#
# <hr>
#
# ## <font style="color:#bd0a6d">Please UPVOTE if you LIKE my EFFORT</font>
#
#
# ### Follow me:
#
# * <a href="https://bit.ly/tarungithub"><img src="data:image/svg+xml;base64,..." width="22" align="left" style="margin-right:10px"/> GitHub</a>
# * <a href="https://bit.ly/tarnkr-youtube"><img src="data:image/svg+xml;base64,..." width="22" align="left" style="margin-right:10px"/>Youtube<a/>
# * <a href="https://medium.com/@codeeasy"><img src="data:image/svg+xml;base64,..."  width="22" align="left" style="margin-right:10px"/> Medium</a>
# * <a href="https://www.linkedin.com/in/tarun-kumar-iit-ism/"><img src="data:image/svg+xml;base64,..." width="22" align="left" style="margin-right:10px"/>Linkedin</a>
#
#
# <hr>
#
# ### Sources
# * [India Dashboard-Covid19](https://www.covid19india.org/)
#
# **Few basic visualization related to India. I will be updating with more visualization in further commits.**
# ### Dataset:
# This dataset is provided by https://api.rootnet.in/

# %% [markdown]
# ## Required imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker
import folium
import branca
from datetime import datetime, timedelta,date
import plotly.express as px
import json, requests

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## Analysis of Tests done in India and Comparission with South Korea
# <hr>
# **Note:** I am working on more on testing data and comparisions insights and will adding soon.

# %%
df_india_test = pd.io.json.json_normalize(requests.get('https://api.rootnet.in/covid19-in/stats/testing/history').json()['data']).rename(columns = {"totalIndividualsTested":"c_individualtest","totalPositiveCases":"c_positive","totalSamplesTested":"c_tests"})

# %%
df_india_test["p2t_ratio"]= np.round(100*df_india_test["c_positive"]/df_india_test["c_tests"],2)
df_india_test["positive"] = df_india_test["c_positive"].diff()
df_india_test["tests"] = df_india_test["c_tests"].diff()
df_india_test["p2t_ratio"]= np.round(100*df_india_test["positive"]/df_india_test["tests"],2)
df_india_test = df_india_test[1:]

# %%
f = plt.figure(figsize=(10,5))
f.add_subplot(111)

plt.axes(axisbelow=True)
plt.bar(df_india_test["day"],df_india_test["tests"].values[:],color="darkcyan",label="Test (Negetive)"+str())
plt.bar(df_india_test["day"],df_india_test["positive"].values[:],bottom=df_india_test["tests"].values[:]-df_india_test["positive"].values[:],color="Red",label="Test (Positive)")
plt.tick_params(size=5,labelsize = 13)
plt.tick_params(axis="x",size=5,labelsize = 13,labelrotation=60 )
plt.xlabel("Date",fontsize=18)
plt.ylabel("Test Results",fontsize=18)

# X-axis
date = df_india_test["day"].values
plt.xticks(list(np.arange(0,len(date),int(len(date)/5))),date[:-1:int(len(date)/5)])

plt.title("Tests in India",fontsize=20)
plt.grid(alpha=0.3)
plt.legend()
plt.savefig('Test_India.png')

# %%
df_india_test["day"].values.shape
# Out:
# (185,)

# %% [markdown]
# ## Number of Test in India till date

# %%
df_india_test["c_tests"][-1:].values[0]
# Out:
# 63661060.0

# %% [markdown]
# ## Test Conducted per Million People

# %%
np.round(1000000*df_india_test["c_tests"][-1:].values[0]/1300000000,2)
# Out:
# 48970.05

# %% [markdown]
# This is far less than the tests happening in South Korea, Singapore and Other countries. Here is a comparison table for India and South Korea <br>**(Last Update: 31 Mar 2020)**
# <table>
#     <tr>
#         <th style = "text-align:Left">Parameters</th>
#         <th>India</th>
#         <th>South Korea</th>
#     </tr>
#     <tr>
#         <th style = "text-align:Left">Population</th>
#         <td>130 Cr</td>
#         <td>5.15 Cr</td>
#     </tr>
#     <tr>
#         <th style = "text-align:Left">First Case Reported</th>
#         <td>28 Jan 2020</td>
#         <td>23 Jan 2020</td>
#     </tr>
#     <tr>
#         <th style = "text-align:Left">Total Tests</th>
#         <td>37000</td>
#         <td>395194</td>
#     </tr>
#     <tr>
#         <th style = "text-align:Left">Tests Per Million Peoples</th>
#         <td>28.46</td>
#         <td>7674</td>
#     </tr>
#     <tr>
#         <th style = "text-align:Left">Positives</th>
#         <td>1250</td>
#         <td>9661</td>
#     </tr>
#     <tr>
#         <th style = "text-align:Left">No. Positives in 100 Tests</th>
#         <td>3.38</td>
#         <td>2.44</td>
#     </tr>
#     <tr>
#         <th style = "text-align:Left">Current Mortality Rate</th>
#         <td>3.76</td>
#         <td>1.63</td>
#     </tr>
# </table><br>
# From this table, this can be concluded that India is far behind in terms of testing, and testing is very important to keep track of COVID19 spread and also to quarantine those people or isolate them to control the spread of COVID19 as done by South Korea.

# %% [markdown]
# ## COVID19 Cases in India
# <hr>

# %%
india_data_json = requests.get('https://api.rootnet.in/covid19-in/unofficial/covid19india.org/statewise').json()
df_india = pd.io.json.json_normalize(india_data_json['data']['statewise'])
df_india = df_india.set_index("state")

# %%
total = df_india.sum()
total.name = "Total"
df_t = pd.DataFrame(total,dtype=float).transpose()
df_t["Mortality Rate (per 100)"] = np.round(100*df_t["deaths"]/df_t["confirmed"],2)
df_t.style.background_gradient(cmap='Purples',axis=1)
# Out:
# <style  type="text/css" >
#     #T_72afc4e0_fb6e_11ea_94d0_0242ac130202row0_col0 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_72afc4e0_fb6e_11ea_94d0_0242ac130202row0_col1 {
#             background-color:  #61409b;
#             color:  #f1f1f1;
#         }    #T_72afc4e0_fb6e_11ea_94d0_0242ac130202row0_col2 {
#             background-color:  #faf9fc;
#             color:  #000000;
#         }    #T_72afc4e0_fb6e_11ea_94d0_0242ac130202row0_col3 {
#             background-color:  #e6e5f1;
#             color:  #000000;
#         }    #T_72afc4e0_fb6e_11ea_94d0_0242ac130202row0_col4 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }</style><table id="T_72afc4e0_fb6e_11ea_94d0_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >confirmed</th>        <th class="col_heading level0 col1" >recovered</th>        <th class="col_heading level0 col2" >deaths</th>        <th class="col_heading level0 col3" >active</th>        <th class="col_heading level0 col4" >Mortality Rate (per 100)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_72afc4e0_fb6e_11ea_94d0_0242ac130202level0_row0" class="row_heading level0 row0" >Total</th>
#                         <td id="T_72afc4e0_fb6e_11ea_94d0_0242ac130202row0_col0" class="data row0 col0" >5480949.000000</td>
#                         <td id="T_72afc4e0_fb6e_11ea_94d0_0242ac130202row0_col1" class="data row0 col1" >4388734.000000</td>
#                         <td id="T_72afc4e0_fb6e_11ea_94d0_0242ac130202row0_col2" class="data row0 col2" >87869.000000</td>
#                         <td id="T_72afc4e0_fb6e_11ea_94d0_0242ac130202row0_col3" class="data row0 col3" >1003567.000000</td>
#                         <td id="T_72afc4e0_fb6e_11ea_94d0_0242ac130202row0_col4" class="data row0 col4" >1.600000</td>
#             </tr>
#     </tbody></table>

# %%
df_india["Mortality Rate (per 100)"]= np.round(np.nan_to_num(100*df_india["deaths"]/df_india["confirmed"]),2)
df_india[df_india['deaths'] > 0].style.background_gradient(cmap='Blues',subset=["confirmed"])\
                        .background_gradient(cmap='Reds',subset=["deaths"])\
                        .background_gradient(cmap='Greens',subset=["recovered"])\
                        .background_gradient(cmap='Purples',subset=["active"])\
                        .background_gradient(cmap='YlOrBr',subset=["Mortality Rate (per 100)"])\
                        .format("{:.2f}",subset=["Mortality Rate (per 100)"])
# Out:
# <style  type="text/css" >
#     #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row0_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row0_col3 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row0_col4 {
#             background-color:  #802d05;
#             color:  #f1f1f1;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row1_col0 {
#             background-color:  #81badb;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row1_col1 {
#             background-color:  #60ba6c;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row1_col2 {
#             background-color:  #fcb499;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row1_col3 {
#             background-color:  #eae8f2;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row1_col4 {
#             background-color:  #f6861f;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row2_col0 {
#             background-color:  #65aad4;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row2_col1 {
#             background-color:  #46ae60;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row2_col2 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row2_col3 {
#             background-color:  #d5d5e9;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row2_col4 {
#             background-color:  #fedc82;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row3_col0 {
#             background-color:  #89bedc;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row3_col1 {
#             background-color:  #80ca80;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row3_col2 {
#             background-color:  #fcbda4;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row3_col3 {
#             background-color:  #c5c6e1;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row3_col4 {
#             background-color:  #fb9225;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row4_col0 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row4_col1 {
#             background-color:  #cbeac4;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row4_col2 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row4_col3 {
#             background-color:  #f1eff6;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row4_col4 {
#             background-color:  #da5c0a;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row5_col0 {
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row5_col1 {
#             background-color:  #b2e0ac;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row5_col2 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row5_col3 {
#             background-color:  #dedeed;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row5_col4 {
#             background-color:  #fea030;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row6_col0 {
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row6_col1 {
#             background-color:  #ceecc8;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row6_col2 {
#             background-color:  #fedecf;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row6_col3 {
#             background-color:  #f3f2f8;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row6_col4 {
#             background-color:  #e1640e;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row7_col0 {
#             background-color:  #dce9f6;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row7_col1 {
#             background-color:  #daf0d4;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row7_col2 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row7_col3 {
#             background-color:  #f8f6fa;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row7_col4 {
#             background-color:  #fff2b1;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row8_col0 {
#             background-color:  #dce9f6;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row8_col1 {
#             background-color:  #def2d9;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row8_col2 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row8_col3 {
#             background-color:  #f1f0f6;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row8_col4 {
#             background-color:  #feeda6;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row9_col0 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row9_col1 {
#             background-color:  #e7f6e2;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row9_col2 {
#             background-color:  #fee4d8;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row9_col3 {
#             background-color:  #f6f5f9;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row9_col4 {
#             background-color:  #812d05;
#             color:  #f1f1f1;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row10_col0 {
#             background-color:  #deebf7;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row10_col1 {
#             background-color:  #e1f3dc;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row10_col2 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row10_col3 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row10_col4 {
#             background-color:  #fff8c4;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row11_col0 {
#             background-color:  #e5eff9;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row11_col1 {
#             background-color:  #e8f6e3;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row11_col2 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row11_col3 {
#             background-color:  #f6f4f9;
#             color:  #000000;
#         }    #T_72cf65c0_fb6e_11ea_94d0_0242ac130202row11_col4 {
#             background-color:  #febf4b;
#             color:  #0

# %% [markdown]
# ## 10 Most Affected States

# %%
f = plt.figure(figsize=(10,5))
f.add_subplot(111)

plt.axes(axisbelow=True)
plt.barh(df_india.sort_values('confirmed')["confirmed"].index[-10:],df_india.sort_values('confirmed')["confirmed"].values[-10:],color="darkcyan")
plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Confirmed Cases",fontsize=18)
plt.title("Top 10 States: India (Confirmed Cases)",fontsize=20)
plt.grid(alpha=0.3)
plt.savefig('Top 10 States_India (Confirmed Cases).png')

# %%
f = plt.figure(figsize=(10,5))
f.add_subplot(111)

plt.axes(axisbelow=True)
plt.barh(df_india.sort_values('deaths')["deaths"].index[-10:],df_india.sort_values('deaths')["deaths"].values[-10:],color="crimson")
plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Deaths",fontsize=18)
plt.title("Top 10 States: India (Deaths Cases)",fontsize=20)
plt.grid(alpha=0.3)
plt.savefig('Top 10 States_India (Deaths Cases).png')

# %% [markdown]
# ## Correlation

# %%
df_india.corr().style.background_gradient(cmap='Reds').format("{:.2f}")
# Out:
# <style  type="text/css" >
#     #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row0_col1 {
#             background-color:  #6b010e;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row0_col2 {
#             background-color:  #ab1016;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row0_col3 {
#             background-color:  #980c13;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row0_col4 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row1_col0 {
#             background-color:  #6b010e;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row1_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row1_col2 {
#             background-color:  #be151a;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row1_col3 {
#             background-color:  #b01217;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row1_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row2_col0 {
#             background-color:  #a30f15;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row2_col1 {
#             background-color:  #b31218;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row2_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row2_col3 {
#             background-color:  #860811;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row2_col4 {
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row3_col0 {
#             background-color:  #980c13;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row3_col1 {
#             background-color:  #af1117;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row3_col2 {
#             background-color:  #8c0912;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row3_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row3_col4 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row4_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row4_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row4_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row4_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7367a6f0_fb6e_11ea_94d0_0242ac130202row4_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >confirmed</th>        <th class="col_heading level0 col1" >recovered</th>        <th class="col_heading level0 col2" >deaths</th>        <th class="col_heading level0 col3" >active</th>        <th class="col_heading level0 col4" >Mortality Rate (per 100)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202level0_row0" class="row_heading level0 row0" >confirmed</th>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row0_col1" class="data row0 col1" >1.00</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row0_col2" class="data row0 col2" >0.93</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row0_col3" class="data row0 col3" >0.94</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row0_col4" class="data row0 col4" >0.42</td>
#             </tr>
#             <tr>
#                         <th id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202level0_row1" class="row_heading level0 row1" >recovered</th>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row1_col0" class="data row1 col0" >1.00</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row1_col2" class="data row1 col2" >0.90</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row1_col3" class="data row1 col3" >0.90</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row1_col4" class="data row1 col4" >0.41</td>
#             </tr>
#             <tr>
#                         <th id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202level0_row2" class="row_heading level0 row2" >deaths</th>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row2_col0" class="data row2 col0" >0.93</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row2_col1" class="data row2 col1" >0.90</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row2_col3" class="data row2 col3" >0.96</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row2_col4" class="data row2 col4" >0.51</td>
#             </tr>
#             <tr>
#                         <th id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202level0_row3" class="row_heading level0 row3" >active</th>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row3_col0" class="data row3 col0" >0.94</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row3_col1" class="data row3 col1" >0.90</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row3_col2" class="data row3 col2" >0.96</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row3_col4" class="data row3 col4" >0.41</td>
#             </tr>
#             <tr>
#                         <th id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202level0_row4" class="row_heading level0 row4" >Mortality Rate (per 100)</th>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row4_col0" class="data row4 col0" >0.42</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row4_col1" class="data row4 col1" >0.41</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row4_col2" class="data row4 col2" >0.51</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row4_col3" class="data row4 col3" >0.41</td>
#                         <td id="T_7367a6f0_fb6e_11ea_94d0_0242ac130202row4_col4" class="data row4 col4" >1.00</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Map Visualization (Statewise Inida)
# <hr>

# %%
# Adding Location data (Latitude,Longitude)
locations = {
    "Kerala" : [10.8505,76.2711],
    "Maharashtra" : [19.7515,75.7139],
    "Karnataka": [15.3173,75.7139],
    "Telangana": [18.1124,79.0193],
    "Uttar Pradesh": [26.8467,80.9462],
    "Rajasthan": [27.0238,74.2179],
    "Gujarat":[22.2587,71.1924],
    "Delhi" : [28.7041,77.1025],
    "Punjab":[31.1471,75.3412],
    "Tamil Nadu": [11.1271,78.6569],
    "Haryana": [29.0588,76.0856],
    "Madhya Pradesh":[22.9734,78.6569],
    "Jammu and Kashmir":[33.7782,76.5762],
    "Ladakh": [34.1526,77.5770],
    "Andhra Pradesh":[15.9129,79.7400],
    "West Bengal": [22.9868,87.8550],
    "Bihar": [25.0961,85.3131],
    "Chhattisgarh":[21.2787,81.8661],
    "Chandigarh":[30.7333,76.7794],
    "Uttarakhand":[30.0668,79.0193],
    "Himachal Pradesh":[31.1048,77.1734],
    "Goa": [15.2993,74.1240],
    "Odisha":[20.9517,85.0985],
    "Andaman and Nicobar Islands": [11.7401,92.6586],
    "Puducherry":[11.9416,79.8083],
    "Manipur":[24.6637,93.9063],
    "Mizoram":[23.1645,92.9376],
    "Assam":[26.2006,92.9376],
    "Meghalaya":[25.4670,91.3662],
    "Tripura":[23.9408,91.9882],
    "Arunachal Pradesh":[28.2180,94.7278],
    "Jharkhand" : [23.6102,85.2799],
    "Nagaland": [26.1584,94.5624],
    "Sikkim": [27.5330,88.5122],
    "Dadra and Nagar Haveli":[20.1809,73.0169],
    "Lakshadweep":[10.5667,72.6417],
    "Daman and Diu":[20.4283,72.8397]    
}
df_india["Lat"] = ""
df_india["Long"] = ""

for index in df_india.index :
    if index in locations:
        df_india.loc[df_india.index == index,"Lat"] = locations[index][0]
        df_india.loc[df_india.index == index,"Long"] = locations[index][1]
    else:
        df_india.drop([index],inplace=True)

# %%
india = folium.Map(location=[23,80], zoom_start=4,max_zoom=6,min_zoom=4,height=500,width="80%")
for i in range(0,len(df_india[df_india['confirmed']>0].index)):
    folium.Circle(
        location=[df_india.iloc[i]['Lat'], df_india.iloc[i]['Long']],
        tooltip = "<h5 style='text-align:center;font-weight: bold'>"+df_india.iloc[i].name+"</h5>"+
                    "<hr style='margin:10px;'>"+
                    "<ul style='color: #444;list-style-type:circle;align-item:left;padding-left:20px;padding-right:20px'>"+
        "<li>Confirmed: "+str(df_india.iloc[i]['confirmed'])+"</li>"+
        "<li>Active:   "+str(df_india.iloc[i]['active'])+"</li>"+
        "<li>Recovered:   "+str(df_india.iloc[i]['recovered'])+"</li>"+
        "<li>Deaths:   "+str(df_india.iloc[i]['deaths'])+"</li>"+
        
        "<li>Mortality Rate:   "+str(np.round(df_india.iloc[i]['Mortality Rate (per 100)'],2))+"</li>"+
        "</ul>"
        ,
        radius=(int(np.log2(df_india.iloc[i]['confirmed']+1)))*15000,
        color='#ff6600',
        fill_color='#ff8533',
        fill=True).add_to(india)

india
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # About Me
# <hr>
# I am Tarun Kumar from India.<br>
# Software Developer at Toppr.<br>
# Hobbyist Artist. <br>
# PE Undergrad from IIT ISM Dhanbad. <br>
# Deep Learning, Reinforcement Learning, and Data Science.
# <br>
# <br>
#
# ### Follow me:
#
# * <a href="https://bit.ly/tarungithub"><img src="data:image/svg+xml;base64,..." width="22" align="left" style="margin-right:10px"/> GitHub</a>
# * <a href="https://bit.ly/tarnkr-youtube"><img src="data:image/svg+xml;base64,..." width="22" align="left" style="margin-right:10px"/>Youtube<a/>
# * <a href="https://medium.com/@codeeasy"><img src="data:image/svg+xml;base64,..."  width="22" align="left" style="margin-right:10px"/> Medium</a>
# * <a href="https://www.linkedin.com/in/tarun-kumar-iit-ism/"><img src="data:image/svg+xml;base64,..." width="22" align="left" style="margin-right:10px"/>Linkedin</a>
#
#
# <hr>
#
# # Feedback
# * **Your feedback is much appreciated**
# * **Please UPVOTE if you LIKE this notebook**
# * **Comment if you have any doubts or you found any errors in the notebook**
